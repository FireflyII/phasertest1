# %%
import matplotlib.pyplot as plt
import json
for line in open("/Volumes/TarDisk-128/phaser/SpaceH/phasertest1/logs/test1.txt","r").read().splitlines():
    if line:
        d = json.loads(line)
        plt.plot(d.get("x"), -d.get("y"),'.b')

# %%
for line in open("/Volumes/TarDisk-128/phaser/SpaceH/phasertest1/logs/test3.txt","r").read().splitlines():
    if line:
        for d in json.loads(line):
            plt.plot(d.get("x"), -d.get("y"),'.b')
